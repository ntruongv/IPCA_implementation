# %%
import datetime
import altair as alt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time 
import multiprocessing as mp
from sklearn.decomposition import PCA
char = ['beta','a2me','log_at','ato','beme','c','cto','d2a','dpi2a','e2p','fc2y',
       'free_cf','idio_vol','investment','lev','size','lturnover','noa','oa','ol','pcm',
        'pm','prof','q','rel_to_high_price','rna','roa','roe',
        'cum_return_12_2','cum_return_12_7','cum_return_1_0','cum_return_36_13',
        's2p','sga2s','spread_mean','suv']

df_ = pd.read_csv("../Data/Characteristics Freyberger et al.csv", index_col = 0)
df_['size'] = np.log10(df_['lme'])
df_['log_at'] = np.log10(df_['at'])
df_['sga2s'] = df_['sga2m']/df_['a2me']/df_['ato']
df_.sort_values(by = ['yy', 'mm', 'permno']);

print("Column names:\n", list(df_))
df = df_.iloc[np.random.choice(df_.shape[0], 100),:][['yy','mm','date','permno','ret']+char]
print("Dataframe shape:", df_.shape)
print("Number of unique stocks:", pd.unique(df_['permno']).shape[0])
print("Number of unique dates:", pd.unique(df_['date']).shape[0])
print("Sub-sampled dataframe shape:", df.shape)
df.head()

stocks = pd.unique(df_['permno'])
N = stocks.shape[0]
Ts = pd.unique(df_['date']).tolist()
Ts = [t for t in Ts if not (int(t[-2:])<=70 and int(t[-2:])>=60)]
T = len(Ts)

# # Generate Zt's 
# N_s_by_t = []
# common_stocks = np.loadtxt("./common_stocks.csv", dtype=np.int)
# Zts = np.zeros((len(common_stocks),len(char),len(Ts)))
# rs = np.zeros((len(common_stocks),len(Ts)))
# for i_t in range(T): 
#     t = Ts[i_t]  # date 
#     df_t = df_.loc[df_['date']==t,['permno','ret']+char]
#     df_t = df_t.loc[df_t['permno'].apply(lambda x: x in set(common_stocks)),:]
#     Zt = df_t.sort_values(by="permno")
#     if not i_t % 100: print(t, Zt.shape[0])
#     N_s_by_t.append(Zt.shape[0])
#     # Zts.append(Zt[char])
#     Zts[:,:,i_t] = Zt[char]
#     rs[:,i_t] = df_t['ret']
# Zts_save = np.array(Zts, copy=True)

# # Augment characteristics 
# Zts = np.array(Zts_save, copy=True)

# # normalize rank 
# Zts = np.argsort(Zts, axis=0)/Zts.shape[0]-.5
# print("Zts.shape (N,L,T)", Zts.shape)
# print("np.amax(Zts)", np.amax(Zts))
# print("np.amin(Zts)", np.amin(Zts))

# Zt_cov = np.zeros((Zts.shape[1],Zts.shape[1],Zts.shape[2]))
# x_t = np.zeros((Zts.shape[1],Zts.shape[2]))
# for i_t in range(Zts.shape[2]):
#     Zt = Zts[:,:,i_t]
#     Zt_cov[:,:,i_t] = (Zt.T).dot(Zt)
#     if i_t<Zts.shape[2]-1:
#         x_t[:,i_t] = (Zt.T).dot(rs[:,i_t+1])
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Column names:
#  ['yy', 'mm', 'date', 'permno', 'ret', 'q10', 'q20', 'q50', 'prc', 'a2me', 'ato', 'beme', 'c', 'cto', 'd2a', 'dpi2a', 'e2p', 'fc2y', 'free_cf', 'investment', 'lme', 'lturnover', 'noa', 'oa', 'ol', 'pcm', 'pm', 'prof', 'q', 'rna', 'roa', 'roe', 's2p', 'sga2m', 'at', 'beta', 'cum_return_12_2', 'cum_return_12_7', 'cum_return_1_0', 'cum_return_36_13', 'idio_vol', 'spread_mean', 'suv', 'rel_to_high_price', 'lev', 'size', 'log_at', 'sga2s']
# Dataframe shape: (1048575, 48)
# Number of unique stocks: 7593
# Number of unique dates: 623
# Sub-sampled dataframe shape: (100, 41)

# %% [markdown]
# ## Preprocessing Common Stocks and Zts

# %%
T = len(Ts)
stocks = np.sort(stocks)
stock_presence = np.empty((stocks.shape[0],T),dtype='bool')
for i_t in range(T): 
    t = Ts[i_t]  # date 
    df_t = df_.loc[df_['date']==t,['yy','permno']]
    stock_presence[:,i_t] = np.isin(stocks,df_t['permno'].unique())

# Generate Zt's 
N_s_by_t = []
common_stocks = stocks #np.loadtxt("./common_stocks.csv", dtype=np.int)
start=time.time()
Zts = np.zeros((len(common_stocks),len(char),len(Ts))) + 1e20
rs = np.zeros((len(common_stocks),len(Ts)))
for i_t in range(T): 
    t = Ts[i_t]  # date 
    df_t = df_.loc[df_['date']==t,['permno','ret']+char]
    #df_t = df_t.loc[df_t['permno'].apply(lambda x: x in set(common_stocks)),:]
    Zt = df_t.sort_values(by="permno")
    if not i_t % 100: print(t, Zt.shape[0])
    N_s_by_t.append(Zt.shape[0])
    # Zts.append(Zt[char])
    Zts[stock_presence[:,i_t],:,i_t] = Zt[char]
    rs[stock_presence[:,i_t],i_t] = df_t['ret']
Zts_save = np.array(Zts, copy=True)
rs_save = np.array(rs,copy=True)
# Out:
# 1/31/71 1191
# 5/31/79 1464
# 9/30/87 2587
# 1/31/96 3088
# 5/31/04 1575
# 9/30/12 999

# %%
# Zts[np.abs(Zts)<1e-20] = Zts[np.abs(Zts)<1e-20] + 1e20
Zts_test = np.argsort(Zts, axis=0)/np.sum(stock_presence, axis=0)-.5
print("Zts.shape (N,L,T)", Zts_test.shape)
print("np.amax(Zts)", np.amax(Zts_test))
print("np.amin(Zts)", np.amin(Zts_test))


# Zts_test = np.argsort(Zts[np.abs(Zts)>1e-12], axis=0)/np.sum(stock_presence, axis=0)-.5
# print("Zts.shape (N,L,T)", Zts_test.shape)
# print("np.amax(Zts)", np.amax(Zts_test))
# print("np.amin(Zts)", np.amin(Zts_test))
# Out:
# Zts.shape (N,L,T) (7593, 36, 521)
# np.amax(Zts) 7.375518672199171
# np.amin(Zts) -0.5

# %% [markdown]
# ## Rolling Window Approach

# %%
# %load_ext autoreload
# %autoreload 2
from ipca_restricted import ipca_restricted

# K = 5
for K in range(1,5):
    T_window = 120
    fact_ret = np.zeros((K,T-T_window+1))
    for i_t in range(T_window,T):
        start_time =time.time()
        common_stock_index = np.prod(stock_presence[:,(i_t-T_window):i_t],axis=1,dtype='bool')
        # Generate Zt's 
        Zts = np.array(Zts_save[common_stock_index, :, (i_t-T_window):i_t], copy=True)
        rs = np.array(rs_save[common_stock_index,(i_t-T_window):i_t], copy=True)
        #print(Zts.shape)
        Zts = np.argsort(Zts,axis=0)/Zts.shape[0]-.5
        Zt_cov = np.zeros((Zts.shape[1],Zts.shape[1],Zts.shape[2]))
        x_t = np.zeros((Zts.shape[1],Zts.shape[2]))
        for i in range(Zts.shape[2]):
            Zt = Zts[:,:,i]
            Zt_cov[:,:,i] = (Zt.T).dot(Zt)
            if i<Zts.shape[2]-1:
                x_t[:,i] = (Zt.T).dot(rs[:,i+1])
        mid_time = time.time()
        F_1, Gamma_b_0, max_abs_delta_F, max_abs_delta_Gamma_b, _, _ \
            = ipca_restricted(Zts, Zt_cov, x_t, K, T_window, init = True)
        # Compute out of sample realized factor 
        fact_ret[:,i_t-T_window]= np.linalg.inv((Gamma_b_0.T).dot(Zt_cov[:,:,-1]).dot(Gamma_b_0))\
            .dot(Gamma_b_0.T).dot(Zts[:,:,-1].T).dot(rs_save[common_stock_index,i_t])
        end_time = time.time()
        print('iteration', i_t)
        #print('fact_return', fact_ret)
        #print('preprocess time', mid_time - start_time)
        #print('alg time', end_time - mid_time)
        print('total time', end_time - start_time)
        #if not i_t %100:
        #    print(i_t)

    #UNIVARIATE SHARPE RATIO
    fact_mean_ret = np.mean(fact_ret,axis=1)
    fact_var = np.var(fact_ret,axis=1)
    single_fact_SR = fact_mean_ret/fact_var 

    np.savetxt("./results/fact_ret_restricted_rand_init_K"+str(K)+".csv", fact_ret, delimiter=",")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# iter 0 	max_abs_delta_F 0.48931075945994956 	max_abs_delta_Gamma_b 0.0887090416540589
# iter 58 	max_abs_delta_F 6.671930993109507e-07 	max_abs_delta_Gamma_b 9.561157428828907e-06
# Elapsed time 2.349886894226074
# iteration 120
# total time 2.638935089111328
# iter 0 	max_abs_delta_F 0.4907347706196587 	max_abs_delta_Gamma_b 0.08380759005403675
# iter 44 	max_abs_delta_F 6.350165764834e-07 	max_abs_delta_Gamma_b 9.629819654298677e-06
# Elapsed time 1.7204639911651611
# iteration 121
# total time 1.987032175064087
# iter 0 	max_abs_delta_F 0.49015681988752774 	max_abs_delta_Gamma_b 0.0855543139317706
# iter 100 	max_abs_delta_F 3.5069836490520764e-05 	max_abs_delta_Gamma_b 0.0006282899716336962
# iter 200 	max_abs_delta_F 7.382830924126996e-06 	max_abs_delta_Gamma_b 0.00012065512793886381
# iter 300 	max_abs_delta_F 1.3890881327038361e-05 	max_abs_delta_Gamma_b 0.00024386103390826379
# iter 400 	max_abs_delta_F 1.6657694048792613e-05 	max_abs_delta_Gamma_b 0.00029240157771910435
# iter 458 	max_abs_delta_F 5.447812256807712e-07 	max_abs_delta_Gamma_b 9.6133075798371e-06
# Elapsed time 17.47630500793457
# iteration 122
# total time 17.66277003288269
# iter 0 	max_abs_delta_F 0.48980737130756946 	max_abs_delta_Gamma_b 0.08534181833201239
# iter 69 	max_abs_delta_F 5.711903465543904e-07 	max_abs_delta_Gamma_b 9.245235563924414e-06
# Elapsed time 2.6476359367370605
# iteration 123
# total time 2.8236117362976074
# iter 0 	max_abs_delta_F 0.4903160921642426 	max_abs_delta_Gamma_b 0.08490191843937074
# iter 100 	max_abs_delta_F 1.429360483326546e-06 	max_abs_delta_Gamma_b 2.2017558071553934e-05
# iter 121 	max_abs_delta_F 6.485287686998779e-07 	max_abs_delta_Gamma_b 9.983769769445998e-06
# Elapsed time 4.613412857055664
# iteration 124
# total time 4.801279067993164
# iter 0 	max_abs_delta_F 0.49034571696951257 	max_abs_delta_Gamma_b 0.09408207121298175
# iter 61 	max_abs_delta_F 4.823409716594953e-07 	max_abs_delta_Gamma_b 9.445766217536976e-06
# Elapsed time 2.340151071548462
# iteration 125
# total time 2.5175838470458984
# iter 0 	max_abs_delta_F 0.49011551992142444 	max_abs_delta_Gamma_b 0.09268697679157059
# iter 100 	max_abs_delta_F 1.9620288458579143e-06 	max_abs_delta_Gamma_b 2.8362280549212585e-05
# iter 123 	max_abs_delta_F 6.887479523054335e-07 	max_abs_delta_Gamma_b 9.958736112875878e-06
# Elapsed time 4.681941986083984
# iteration 126
# total time 4.875061988830566
# iter 0 	max_abs_delta_F 0.4891282007784532 	max_abs_delta_Gamma_b 0.09305427197847717
# iter 55 	max_abs_delta_F 6.595568607118229e-07 	max_abs_delta_Gamma_b 9.731161195340847e-06
# Elapsed time 2.123310089111328
# iteration 127
# total time 2.3044068813323975
# iter 0 	max_abs_delta_F 0.489371120459785 	max_abs_delta_Gamma_b 0.0876342304103973
# iter 94 	max_abs_delta_F 5.972585095541317e-07 	max_abs_delta_Gamma_b 9.611430091400074e-06
# Elapsed time 3.5566978454589844
# iteration 128
# total time 3.7395098209381104
# iter 0 	max_abs_delta_F 0.48955393811605136 	max_abs_delta_Gamma_b 0.08596449599530769
# iter 73 	max_abs_delta_F 6.564523373067684e-07 	max_abs_delta_Gamma_b 9.526497287169004e-06
# Elapsed time 2.7792928218841553
# iteration 129
# total time 2.9747462272644043
# iter 0 	max_abs_delta_F 0.49051897817154616 	max_abs_delta_Gamma_b 0.0810633805665899
# iter 50 	max_abs_delta_F 6.735249195378206e-07 	max_abs_delta_Gamma_b 9.664224740837647e-06
# Elapsed time 1.9170312881469727
# iteration 130
# total time 2.100044012069702
# iter 0 	max_abs_delta_F 0.4899731159075107 	max_abs_delta_Gamma_b 0.09312713006422996
# iter 100 	max_abs_delta_F 2.5549672618180977e-06 	max_abs_delta_Gamma_b 3.436295984336898e-05
# iter 131 	max_abs_delta_F 7.182838707672051e-07 	max_abs_delta_Gamma_b 9.71581164567508e-06
# Elapsed time 4.977839946746826
# iteration 131
# total time 5.175822973251343
# iter 0 	max_abs_delta_F 0.49022532567517035 	max_abs_delta_Gamma_b 0.08159354929382079
# iter 75 	max_abs_delta_F 6.587259212399701e-07 	max_abs_delta_Gamma_b 9.243695535138205e-06
# Elapsed time 2.867828369140625
# iteration 132
# total time 3.051978826522827
# iter 0 	max_abs_delta_F 0.4898527072699646 	max_abs_delta_Gamma_b 0.09414130590596928
# iter 100 	max_abs_delta_F 2.2197736404619583e-05 	max_abs_delta_Gamma_b 0.00034764296610034523
# iter 200 	max_abs_delta_F 5.654309926051069e-06 	max_abs_delta_Gamma_b 8.164333714731808e-05
# iter 239 	max_abs_delta_F 6.620218202537102e-07 	max_abs_delta_Gamma_b 9.590294315782052e-06
# Elapsed time 9.028699159622192
# iteration 133
# total time 9.2309889793396
# iter 0 	max_abs_delta_F 0.4904525673590249 	max_abs_delta_Gamma_b 0.09875924991751021
# iter 68 	max_abs_delta_F 6.391330380512197e-07 	max_abs_delta_Gamma_b 9.275530725333015e-06
# Elapsed time 2.603015184402466
# iteration 134
# total time 2.7877309322357178
# iter 0 	max_abs_delta_F 0.4898658545006539 	max_abs_delta_Gamma_b 0.09227852693528939
# iter 94 	max_abs_delta_F 6.13667773182451e-07 	max_abs_delta_Gamma_b 9.506800294336656e-06
# Elapsed time 3.59474778175354
# iteration 135
# total time 3.778104066848755
# iter 0 	max_abs_delta_F 0.49031775197093574 	max_abs_delta_Gamma_b 0.08811267221826896
# iter 100 	max_abs_delta_F 5.378489358917156e-06 	max_abs_delta_Gamma_b 7.001014287304547e-05
# iter 159 	max_abs_delta_F 7.468617681924643e-07 	max_abs_delta_Gamma_b 9.742445753315341e-06
# Elapsed time 6.031829118728638
# iteration 136
# total time 6.231019973754883
# iter 0 	max_abs_delta_F 0.4896721228888471 	max_abs_delta_Gamma_b 0.08446985853236874
# iter 100 	max_abs_delta_F 1.2429573836321395e-06 	max_abs_delta_Gamma_b 1.6924516560466015e-05
# iter 113 	max_abs_delta_F 7.21574730662768e-07 	max_abs_delta_Gamma_b 9.803852618729936e-06
# Elapsed time 4.2832770347595215
# iteration 137
# total time 4.4683709144592285
# iter 0 	max_abs_delta_F 0.49078418811827285 	max_abs_delta_Gamma_b 0.09170112529050868
# iter 95 	max_abs_delta_F 6.849082465353931e-07 	max_abs_delta_Gamma_b 9.85485196915677e-06
# Elapsed time 3.605694055557251
# iteration 138
# total time 3.807112216949463
# iter 0 	max_abs_delta_F 0.49062889879977134 	max_abs_delta_Gamma_b 0.08113899083698896
# iter 100 	max_abs_delta_F 1.7741397612404689e-06 	max_abs_delta_Gamma_b 3.0416056282954742e-05
# iter 128 	max_abs_delta_F 5.698678471422487e-07 	max_abs_delta_Gamma_b 9.756750394768807e-06
# Elapsed time 4.903312921524048
# iteration 139
# total time 5.088247060775757
# iter 0 	max_abs_delta_F 0.48998441720847047 	max_abs_delta_Gamma_b 0.08960513229189389
# iter 100 	max_abs_delta_F 2.4737901597565176e-06 	max_abs_delta_Gamma_b 4.115181122972872e-05
# iter 149 	max_abs_delta_F 5.986995528081562e-07 	max_abs_delta_Gamma_b 9.98178737808414e-06
# Elapsed time 5.877878904342651
# iteration 140
# total time 6.069399118423462
# iter 0 	max_abs_delta_F 0.4891205686004134 	max_abs_delta_Gamma_b 0.08981459472336396
# iter 100 	max_abs_delta_F 5.878583382344606e-06 	max_abs_delta_Gamma_b 0.00010358048001802927
# iter 139 	max_abs_delta_F 5.440821139425035e-07 	max_abs_delta_Gamma_b 9.446575398221914e-06
# Elapsed time 5.348668098449707
# iteration 141
# total time 5.533147811889648
# iter 0 	max_abs_delta_F 0.49001369816648593 	max_abs_delta_Gamma_b 0.08878352828427014
# iter 100 	max_abs_delta_F 6.623045218923792e-07 	max_abs_delta_Gamma_b 9.986829192825526e-06
# Elapsed time 3.877379894256592
# iteration 142
# total time 4.060704946517944
# iter 0 	max_abs_delta_F 0.49044068402513635 	max_abs_delta_Gamma_b 0.09061503356552611
# iter 100 	max_abs_delta_F 1.4969091925670046e-06 	max_abs_delta_Gamma_b 3.1482537300957816e-05
# iter 148 	max_abs_delta_F 4.5708582412022983e-07 	max_abs_delta_Gamma_b 9.883541782178147e-06
# Elapsed time 5.754947185516357
# iteration 143
# total time 5.943051815032959
# iter 0 	max_abs_delta_F 0.49069847810051653 	max_abs_delta_Gamma_b 0.08813495293539649
# iter 100 	max_abs_delta_F 6.867883506096278e-07 	max_abs_delta_Gamma_b 1.1309203658461807e-05
# iter 102 	max_abs_delta_F 5.371140492383397e-07 	max_abs_delta_Gamma_b 8.84492547022562e-06
# Elapsed time 3.9090800285339355
# iteration 144
# total time 4.0922768115997314
# iter 0 	max_abs_delta_F 0.49075467899258113 	max_abs_delta_Gamma_b 0.0933377715296428
# iter 100 	max_abs_delta_F 4.2989589622312254e-06 	max_abs_delta_Gamma_b 5.694771689758451e-05
# iter 200 	max_abs_delta_F 8.463901564128319e-07 	max_abs_delta_Gamma_b 1.1377707712906124e-05
# iter 209 	max_abs_delta_F 7.378606493138455e-07 	max_abs_delta_Gamma_b 9.924051115212888e-06
# Elapsed time 7.969011068344116
# iteration 145
# total time 8.157927989959717
# iter 0 	max_abs_delta_F 0.4894983098982256 	max_abs_delta_Gamma_b 0.08729399145691766
# iter 100 	max_abs_delta_F 1.0972779675413064e-06 	max_abs_delta_Gamma_b 1.4549315945227413e-05
# iter 107 	max_abs_delta_F 7.417083914860962e-07 	max_abs_delta_Gamma_b 9.834931823736208e-06
# Elapsed time 4.127557039260864
# iteration 146
# total time 4.31374716758728
# iter 0 	max_abs_delta_F 0.4896230620760289 	max_abs_delta_Gamma_b 0.08192885545843315
# iter 40 	max_abs_delta_F 7.106932382988293e-07 	max_abs_delta_Gamma_b 9.311258902570257e-06
# Elapsed time 1.5552759170532227
# iteration 147
# total time 1.7374131679534912
# iter 0 	max_abs_delta_F 0.4896807076842391 	max_abs_delta_Gamma_b 0.08468485688072937
# iter 99 	max_abs_delta_F 6.974813466736691e-07 	max_abs_delta_Gamma_b 9.997285098780073e-06
# Elapsed time 3.7896902561187744
# iteration 148
# total time 3.972597122192383
# iter 0 	max_abs_delta_F 0.4891752880283739 	max_abs_delta_Gamma_b 0.09724445748863096
# iter 95 	max_abs_delta_F 5.581102185627963e-07 	max_abs_delta_Gamma_b 9.894843984762276e-06
# Elapsed time 3.669217109680176
# iteration 149
# total time 3.8538520336151123
# iter 0 	max_abs_delta_F 0.48988339606780906 	max_abs_delta_Gamma_b 0.09053976333844652
# iter 100 	max_abs_delta_F 4.008412421544403e-06 	max_abs_delta_Gamma_b 4.906025373020635e-05
# iter 134 	max_abs_delta_F 7.995561446421358e-07 	max_abs_delta_Gamma_b 9.78465995240653e-06
# Elapsed time 5.14181923866272
# iteration 150
# total time 5.358332872390747
# iter 0 	max_abs_delta_F 0.48956111054808543 	max_abs_delta_Gamma_b 0.0852211285308224
# iter 71 	max_abs_delta_F 4.835644851036524e-07 	max_abs_delta_Gamma_b 9.087578077156435e-06
# Elapsed time 2.7300899028778076
# iteration 151
# total time 2.9191319942474365
# iter 0 	max_abs_delta_F 0.49144547393426813 	max_abs_delta_Gamma_b 0.09425732186301493
# iter 98 	max_abs_delta_F 7.602514755808766e-07 	max_abs_delta_Gamma_b 9.709580925018381e-06
# Elapsed time 3.7479240894317627
# iteration 152
# total time 3.9352877140045166
# iter 0 	max_abs_delta_F 0.4907608222937681 	max_abs_delta_Gamma_b 0.09083301090723231
# iter 100 	max_abs_delta_F 1.1838106311220968e-06 	max_abs_delta_Gamma_b 2.088311246982361e-05
# iter 129 	max_abs_delta_F 5.612705242110433e-07 	max_abs_delta_Gamma_b 9.893848543749922e-06
# Elapsed time 4.9337849617004395
# iteration 153
# total time 5.126534938812256
# iter 0 	max_abs_delta_F 0.4908893070550176 	max_abs_delta_Gamma_b 0.08231703572583864
# iter 73 	max_abs_delta_F 6.556471289029293e-07 	max_abs_delta_Gamma_b 9.637789420635858e-06
# Elapsed time 2.8340981006622314
# iteration 154
# total time 3.021270751953125
# iter 0 	max_abs_delta_F 0.4909023661774071 	max_abs_delta_Gamma_b 0.08566033972421956
# iter 37 	max_abs_delta_F 6.52285467630612e-07 	max_abs_delta_Gamma_b 8.282152981210805e-06
# Elapsed time 1.4457027912139893
# iteration 155
# total time 1.6362650394439697
# iter 0 	max_abs_delta_F 0.4909395723341127 	max_abs_delta_Gamma_b 0.09792362065500855
# iter 100 	max_abs_delta_F 4.189592012282031e-06 	max_abs_delta_Gamma_b 6.607100163267015e-05
# iter 145 	max_abs_delta_F 6.27599451989083e-07 	max_abs_delta_Gamma_b 9.898009489612901e-06
# Elapsed time 5.721405744552612
# iteration 156
# total time 5.912164926528931
# iter 0 	max_abs_delta_F 0.490033996742824 	max_abs_delta_Gamma_b 0.09189972679230632
# iter 71 	max_abs_delta_F 6.901800192776086e-07 	max_abs_delta_Gamma_b 9.80169734905755e-06
# Elapsed time 2.9691901206970215
# iteration 157
# total time 3.1776580810546875
# iter 0 	max_abs_delta_F 0.48919852006753234 	max_abs_delta_Gamma_b 0.08264346468633621
# iter 100 	max_abs_delta_F 2.8586830557533552e-06 	max_abs_delta_Gamma_b 5.267591794316238e-05
# iter 129 	max_abs_delta_F 5.195539080502851e-07 	max_abs_delta_Gamma_b 9.504542707897405e-06
# Elapsed time 5.454601287841797
# iteration 158
# total time 5.648510217666626
# iter 0 	max_abs_delta_F 0.49027550576744444 	max_abs_delta_Gamma_b 0.08800000733001609
# iter 96 	max_abs_delta_F 5.728332143117566e-07 	max_abs_delta_Gamma_b 9.495870782715523e-06
# Elapsed time 3.6870479583740234
# iteration 159
# total time 3.873136281967163
# iter 0 	max_abs_delta_F 0.49080588490790283 	max_abs_delta_Gamma_b 0.0902524174001078
# iter 63 	max_abs_delta_F 5.875776249989114e-07 	max_abs_delta_Gamma_b 8.933384834660399e-06
# Elapsed time 2.449071168899536
# iteration 160
# total time 2.6414098739624023
# iter 0 	max_abs_delta_F 0.48970958625203487 	max_abs_delta_Gamma_b 0.08468250368605393
# iter 100 	max_abs_delta_F 2.0532998346306892e-06 	max_abs_delta_Gamma_b 3.106836183839791e-05
# iter 125 	max_abs_delta_F 6.597458538477216e-07 	max_abs_delta_Gamma_b 9.975063423964433e-06
# Elapsed time 4.749191761016846
# iteration 161
# total time 4.935699939727783
# iter 0 	max_abs_delta_F 0.4891683035491682 	max_abs_delta_Gamma_b 0.07930343080837085
# iter 100 	max_abs_delta_F 5.035682100041337e-06 	max_abs_delta_Gamma_b 8.757896247737529e-05
# iter 174 	max_abs_delta_F 5.657482881642021e-07 	max_abs_delta_Gamma_b 9.726085520570366e-06
# Elapsed time 6.5385518074035645
# iteration 162
# total time 6.742444753646851
# iter 0 	max_abs_delta_F 0.4909772532418736 	max_abs_delta_Gamma_b 0.0950493394597528
# iter 94 	max_abs_delta_F 5.168755396783126e-07 	max_abs_delta_Gamma_b 9.973559702155729e-06
# Elapsed time 3.5541458129882812
# iteration 163
# total time 3.7406980991363525
# iter 0 	max_abs_delta_F 0.4900823956725103 	max_abs_delta_Gamma_b 0.08555447607379138
# iter 100 	max_abs_delta_F 2.237578232867322e-06 	max_abs_delta_Gamma_b 4.0740134093919494e-05
# iter 123 	max_abs_delta_F 5.331538419831185e-07 	max_abs_delta_Gamma_b 9.64649943497611e-06
# Elapsed time 4.6567699909210205
# iteration 164
# total time 4.8419578075408936
# iter 0 	max_abs_delta_F 0.48882669837917836 	max_abs_delta_Gamma_b 0.09818174851340483
# iter 62 	max_abs_delta_F 5.463874519277821e-07 	max_abs_delta_Gamma_b 9.007078658951533e-06
# Elapsed time 2.3482351303100586
# iteration 165
# total time 2.5342297554016113
# iter 0 	max_abs_delta_F 0.4891514605424362 	max_abs_delta_Gamma_b 0.09235057004465261
# iter 100 	max_abs_delta_F 9.45419348746722e-06 	max_abs_delta_Gamma_b 0.0001482849673272751
# iter 180 	max_abs_delta_F 6.278018790547469e-07 	max_abs_delta_Gamma_b 9.83045879896509e-06
# Elapsed time 6.746701240539551
# iteration 166
# total time 6.936837911605835
# iter 0 	max_abs_delta_F 0.49102098324033566 	max_abs_delta_Gamma_b 0.08925136750333768
# iter 71 	max_abs_delta_F 7.320504240207969e-07 	max_abs_delta_Gamma_b 9.501008785542241e-06
# Elapsed time 2.6893858909606934
# iteration 167
# total time 2.8753669261932373
# iter 0 	max_abs_delta_F 0.4904744859216178 	max_abs_delta_Gamma_b 0.08379575914028747
# iter 100 	max_abs_delta_F 6.368916254022046e-06 	max_abs_delta_Gamma_b 0.00010856700331780394
# iter 175 	max_abs_delta_F 5.673302846721411e-07 	max_abs_delta_Gamma_b 9.831269447161871e-06
# Elapsed time 6.60525918006897
# iteration 168
# total time 6.7881598472595215
# iter 0 	max_abs_delta_F 0.489163904563216 	max_abs_delta_Gamma_b 0.08353438402010648
# iter 94 	max_abs_delta_F 6.159799561168471e-07 	max_abs_delta_Gamma_b 9.784803246172762e-06
# Elapsed time 3.5906872749328613
# iteration 169
# total time 3.775855779647827
# iter 0 	max_abs_delta_F 0.4906516067350342 	max_abs_delta_Gamma_b 0.08496277177807104
# iter 100 	max_abs_delta_F 8.105025201094e-06 	max_abs_delta_Gamma_b 0.00011972703624829564
# iter 181 	max_abs_delta_F 6.639652438750613e-07 	max_abs_delta_Gamma_b 9.851087523945995e-06
# Elapsed time 6.917539119720459
# iteration 170
# total time 7.1011011600494385
# iter 0 	max_abs_delta_F 0.49084182448251923 	max_abs_delta_Gamma_b 0.08332515294585571
# iter 88 	max_abs_delta_F 6.738932018170657e-07 	max_abs_delta_Gamma_b 9.82830361237487e-06
# Elapsed time 3.3610870838165283
# iteration 171
# total time 3.5481629371643066
# iter 0 	max_abs_delta_F 0.4904325445827025 	max_abs_delta_Gamma_b 0.09235198111780538
# iter 91 	max_abs_delta_F 6.730762560305857e-07 	max_abs_delta_Gamma_b 9.82075324599806e-06
# Elapsed time 3.4326717853546143
# iteration 172
# total time 3.6124038696289062
# iter 0 	max_abs_delta_F 0.49044717080979516 	max_abs_delta_Gamma_b 0.08768140081384815
# iter 99 	max_abs_delta_F 6.60064561197852e-07 	max_abs_delta_Gamma_b 9.952016492316929e-06
# Elapsed time 3.7283332347869873
# iteration 173
# total time 3.9069719314575195
# iter 0 	max_abs_delta_F 0.4903122510913799 	max_abs_delta_Gamma_b 0.08576055640969184
# iter 100 	max_abs_delta_F 5.60988466820163e-06 	max_abs_delta_Gamma_b 0.000111119264529813
# iter 200 	max_abs_delta_F 1.075295877270422e-06 	max_abs_delta_Gamma_b 2.1220474638265648e-05
# iter 239 	max_abs_delta_F 4.993791873937653e-07 	max_abs_delta_Gamma_b 9.851935325813594e-06
# Elapsed time 8.978857040405273
# iteration 174
# total time 9.198109865188599
# iter 0 	max_abs_delta_F 0.49006203646584334 	max_abs_delta_Gamma_b 0.0856401143342971
# iter 100 	max_abs_delta_F 1.3080046821358493e-06 	max_abs_delta_Gamma_b 1.9712072998346565e-05
# iter 112 	max_abs_delta_F 6.300953670322287e-07 	max_abs_delta_Gamma_b 9.503154898740092e-06
# Elapsed time 4.221948862075806
# iteration 175
# total time 4.406634092330933
# iter 0 	max_abs_delta_F 0.4901755078041907 	max_abs_delta_Gamma_b 0.0763529912431935
# iter 61 	max_abs_delta_F 6.745243432174914e-07 	max_abs_delta_Gamma_b 9.309655347595688e-06
# Elapsed time 2.3138251304626465
# iteration 176
# total time 2.491386890411377
# iter 0 	max_abs_delta_F 0.49176840311111913 	max_abs_delta_Gamma_b 0.07855385232187226
# iter 100 	max_abs_delta_F 2.56507516186181e-06 	max_abs_delta_Gamma_b 3.72253036615759e-05
# iter 125 	max_abs_delta_F 6.555878278218139e-07 	max_abs_delta_Gamma_b 9.486267381324239e-06
# Elapsed time 4.688195705413818
# iteration 177
# total time 4.866897106170654
# iter 0 	max_abs_delta_F 0.4903582666246726 	max_abs_delta_Gamma_b 0.08354433903888411
# iter 100 	max_abs_delta_F 9.144194419129603e-06 	max_abs_delta_Gamma_b 0.0001832370125525997
# iter 192 	max_abs_delta_F 4.822112928827323e-07 	max_abs_delta_Gamma_b 9.759982612433302e-06
# Elapsed time 7.1990320682525635
# iteration 178
# total time 7.375884056091309
# iter 0 	max_abs_delta_F 0.4906228386620009 	max_abs_delta_Gamma_b 0.09200907381016836
# iter 100 	max_abs_delta_F 7.484374783750947e-07 	max_abs_delta_Gamma_b 1.2011609700900458e-05
# iter 104 	max_abs_delta_F 6.138860725738665e-07 	max_abs_delta_Gamma_b 9.850379096043669e-06
# Elapsed time 3.939739227294922
# iteration 179
# total time 4.115042209625244
# iter 0 	max_abs_delta_F 0.49236206292567225 	max_abs_delta_Gamma_b 0.0708059765659538
# iter 100 	max_abs_delta_F 2.6281899280814604e-06 	max_abs_delta_Gamma_b 4.068758694655299e-05
# iter 131 	max_abs_delta_F 6.113904634920719e-07 	max_abs_delta_Gamma_b 9.573175871395117e-06
# Elapsed time 4.927950143814087
# iteration 180
# total time 5.124563932418823
# iter 0 	max_abs_delta_F 0.49071133264022454 	max_abs_delta_Gamma_b 0.08002808229423357
# iter 100 	max_abs_delta_F 2.246051340264155e-06 	max_abs_delta_Gamma_b 3.885831904487751e-05
# iter 146 	max_abs_delta_F 5.825837345753119e-07 	max_abs_delta_Gamma_b 9.785497290309218e-06
# Elapsed time 5.495995044708252
# iteration 181
# total time 5.679322004318237
# iter 0 	max_abs_delta_F 0.4904025962893483 	max_abs_delta_Gamma_b 0.07753177946858082
# iter 100 	max_abs_delta_F 1.7040010154882536e-06 	max_abs_delta_Gamma_b 2.2978029556429945e-05
# iter 128 	max_abs_delta_F 7.348269607516678e-07 	max_abs_delta_Gamma_b 9.907921443689373e-06
# Elapsed time 4.816766977310181
# iteration 182
# total time 4.998902082443237
# iter 0 	max_abs_delta_F 0.49035492209739384 	max_abs_delta_Gamma_b 0.08724986870815987
# iter 100 	max_abs_delta_F 1.992977535238387e-06 	max_abs_delta_Gamma_b 3.347298447505469e-05
# iter 140 	max_abs_delta_F 5.593845771292303e-07 	max_abs_delta_Gamma_b 9.753681914603738e-06
# Elapsed time 5.261955976486206
# iteration 183
# total time 5.443082094192505
# iter 0 	max_abs_delta_F 0.4899342311639915 	max_abs_delta_Gamma_b 0.08683686458125413
# iter 51 	max_abs_delta_F 7.488884088665086e-07 	max_abs_delta_Gamma_b 9.615662207405973e-06
# Elapsed time 1.9799480438232422
# iteration 184
# total time 2.1612470149993896
# iter 0 	max_abs_delta_F 0.48961848794480883 	max_abs_delta_Gamma_b 0.0763975979854135
# iter 74 	max_abs_delta_F 5.18658758117986e-07 	max_abs_delta_Gamma_b 9.626326121946714e-06
# Elapsed time 2.8275489807128906
# iteration 185
# total time 3.00618314743042
# iter 0 	max_abs_delta_F 0.49044737699978863 	max_abs_delta_Gamma_b 0.08072854240627293
# iter 100 	max_abs_delta_F 5.503875293577094e-05 	max_abs_delta_Gamma_b 0.0008484420128306774
# iter 200 	max_abs_delta_F 2.509748252845194e-06 	max_abs_delta_Gamma_b 3.92962039045642e-05
# iter 237 	max_abs_delta_F 6.166262879775723e-07 	max_abs_delta_Gamma_b 9.702390131916388e-06
# Elapsed time 9.014500141143799
# iteration 186
# total time 9.194902896881104
# iter 0 	max_abs_delta_F 0.4905188582456677 	max_abs_delta_Gamma_b 0.08462490241320782
# iter 100 	max_abs_delta_F 1.162842011120952e-06 	max_abs_delta_Gamma_b 1.6737694971342097e-05
# iter 132 	max_abs_delta_F 6.903875164244837e-07 	max_abs_delta_Gamma_b 9.925197263001812e-06
# Elapsed time 5.0928051471710205
# iteration 187
# total time 5.264221906661987
# iter 0 	max_abs_delta_F 0.49110904468340905 	max_abs_delta_Gamma_b 0.08530326844015386
# iter 100 	max_abs_delta_F 6.902124617446533e-06 	max_abs_delta_Gamma_b 0.0001041776156221793
# iter 194 	max_abs_delta_F 6.562408264436869e-07 	max_abs_delta_Gamma_b 9.925419752397819e-06
# Elapsed time 7.350615978240967
# iteration 188
# total time 7.526637077331543
# iter 0 	max_abs_delta_F 0.4906627132988624 	max_abs_delta_Gamma_b 0.07913855330835304
# iter 86 	max_abs_delta_F 6.715264184386516e-07 	max_abs_delta_Gamma_b 9.830445606335169e-06
# Elapsed time 3.2766642570495605
# iteration 189
# total time 3.4480209350585938
# iter 0 	max_abs_delta_F 0.490971192461825 	max_abs_delta_Gamma_b 0.07929278420505613
# iter 100 	max_abs_delta_F 6.400787898645471e-07 	max_abs_delta_Gamma_b 1.1087188823542864e-05
# iter 102 	max_abs_delta_F 5.621232205263819e-07 	max_abs_delta_Gamma_b 9.737042002091599e-06
# Elapsed time 3.8461251258850098
# iteration 190
# total time 4.0133421421051025
# iter 0 	max_abs_delta_F 0.49062175184777723 	max_abs_delta_Gamma_b 0.08903217696300961
# iter 69 	max_abs_delta_F 5.874931638449937e-07 	max_abs_delta_Gamma_b 9.097938336586606e-06
# Elapsed time 2.6047492027282715
# iteration 191
# total time 2.773171901702881
# iter 0 	max_abs_delta_F 0.49100687409117105 	max_abs_delta_Gamma_b 0.08381724482313735
# iter 100 	max_abs_delta_F 6.945365727857533e-06 	max_abs_delta_Gamma_b 0.00012905125694005802
# iter 172 	max_abs_delta_F 5.372245781299057e-07 	max_abs_delta_Gamma_b 9.876118315720512e-06
# Elapsed time 6.458733797073364
# iteration 192
# total time 6.620262861251831
# iter 0 	max_abs_delta_F 0.4906692137789529 	max_abs_delta_Gamma_b 0.08384698806977196
# iter 75 	max_abs_delta_F 6.794991878506615e-07 	max_abs_delta_Gamma_b 9.705574637388083e-06
# Elapsed time 2.861212968826294
# iteration 193
# total time 3.0209429264068604
# iter 0 	max_abs_delta_F 0.49019500674238325 	max_abs_delta_Gamma_b 0.07545976977481376
# iter 55 	max_abs_delta_F 7.227326854075819e-07 	max_abs_delta_Gamma_b 9.943182298284742e-06
# Elapsed time 2.108433246612549
# iteration 194
# total time 2.270311117172241
# iter 0 	max_abs_delta_F 0.4900276347375563 	max_abs_delta_Gamma_b 0.07720641465566301
# iter 100 	max_abs_delta_F 2.087170563966737e-06 	max_abs_delta_Gamma_b 3.149773136962179e-05
# iter 125 	max_abs_delta_F 6.561629468579017e-07 	max_abs_delta_Gamma_b 9.90225069623505e-06
# Elapsed time 4.7489540576934814
# iteration 195
# total time 4.909193754196167
# iter 0 	max_abs_delta_F 0.4901547103022028 	max_abs_delta_Gamma_b 0.08300710149687404
# iter 56 	max_abs_delta_F 5.29803084132782e-07 	max_abs_delta_Gamma_b 9.360601262132271e-06
# Elapsed time 2.1241090297698975
# iteration 196
# total time 2.282564163208008
# iter 0 	max_abs_delta_F 0.4899009359786913 	max_abs_delta_Gamma_b 0.07995971298801266
# iter 79 	max_abs_delta_F 5.79734498909578e-07 	max_abs_delta_Gamma_b 9.321078696868154e-06
# Elapsed time 2.9805667400360107
# iteration 197
# total time 3.138209819793701
# iter 0 	max_abs_delta_F 0.48964550389122713 	max_abs_delta_Gamma_b 0.09153946726934502
# iter 100 	max_abs_delta_F 6.154679203965511e-07 	max_abs_delta_Gamma_b 1.0510604501419388e-05
# iter 101 	max_abs_delta_F 5.766114851463825e-07 	max_abs_delta_Gamma_b 9.846851491938995e-06
# Elapsed time 3.804292917251587
# iteration 198
# total time 3.9637439250946045
# iter 0 	max_abs_delta_F 0.4912582091300616 	max_abs_delta_Gamma_b 0.08778059989707053
# iter 41 	max_abs_delta_F 6.086917937848547e-07 	max_abs_delta_Gamma_b 9.679142049026848e-06
# Elapsed time 1.5595040321350098
# iteration 199
# total time 1.7137389183044434
# iter 0 	max_abs_delta_F 0.48970160990916894 	max_abs_delta_Gamma_b 0.07656780691613861
# iter 100 	max_abs_delta_F 1.219051706784095e-06 	max_abs_delta_Gamma_b 1.6976789166546183e-05
# iter 109 	max_abs_delta_F 7.096155252207559e-07 	max_abs_delta_Gamma_b 9.930290430437824e-06
# Elapsed time 4.106709003448486
# iteration 200
# total time 4.260739088058472
# iter 0 	max_abs_delta_F 0.4909023236928965 	max_abs_delta_Gamma_b 0.07106062589498884
# iter 78 	max_abs_delta_F 6.486673793972269e-07 	max_abs_delta_Gamma_b 9.885147370098315e-06
# Elapsed time 2.9595067501068115
# iteration 201
# total time 3.1138710975646973
# iter 0 	max_abs_delta_F 0.49098586344316564 	max_abs_delta_Gamma_b 0.0754106216381322
# iter 72 	max_abs_delta_F 7.189057757128098e-07 	max_abs_delta_Gamma_b 9.744746163505236e-06
# Elapsed time 2.724515676498413
# iteration 202
# total time 2.8771259784698486
# iter 0 	max_abs_delta_F 0.4904233200292123 	max_abs_delta_Gamma_b 0.07704019177536453
# iter 80 	max_abs_delta_F 7.082088797394473e-07 	max_abs_delta_Gamma_b 9.261432908084324e-06
# Elapsed time 3.022897243499756
# iteration 203
# total time 3.1753592491149902
# iter 0 	max_abs_delta_F 0.49083690840972016 	max_abs_delta_Gamma_b 0.07252753218553795
# iter 93 	max_abs_delta_F 5.651769849988105e-07 	max_abs_delta_Gamma_b 9.819402183194702e-06
# Elapsed time 3.4931700229644775
# iteration 204
# total time 3.6451528072357178
# iter 0 	max_abs_delta_F 0.4893796368738167 	max_abs_delta_Gamma_b 0.08746096397033096
# iter 100 	max_abs_delta_F 1.3778163850732046e-06 	max_abs_delta_Gamma_b 1.942153439700938e-05
# iter 114 	max_abs_delta_F 7.078759475073054e-07 	max_abs_delta_Gamma_b 9.996358913410592e-06
# Elapsed time 4.35105299949646
# iteration 205
# total time 4.5011069774627686
# iter 0 	max_abs_delta_F 0.4905103769975916 	max_abs_delta_Gamma_b 0.08296896629726434
# iter 98 	max_abs_delta_F 6.77066912700808e-07 	max_abs_delta_Gamma_b 9.706696950143883e-06
# Elapsed time 3.697309970855713
# iteration 206
# total time 3.8486642837524414
# iter 0 	max_abs_delta_F 0.49030798878295495 	max_abs_delta_Gamma_b 0.09282677965429453
# iter 85 	max_abs_delta_F 6.605118385205737e-07 	max_abs_delta_Gamma_b 9.368835396630269e-06
# Elapsed time 3.2173800468444824
# iteration 207
# total time 3.366063117980957
# iter 0 	max_abs_delta_F 0.4906171626923342 	max_abs_delta_Gamma_b 0.08482063807141578
# iter 100 	max_abs_delta_F 2.34505555726126e-06 	max_abs_delta_Gamma_b 3.3981162214516144e-05
# iter 200 	max_abs_delta_F 1.0618958170246755e-06 	max_abs_delta_Gamma_b 1.5174761279887185e-05
# iter 261 	max_abs_delta_F 7.015876459090009e-07 	max_abs_delta_Gamma_b 9.976872245647811e-06
# Elapsed time 9.78637409210205
# iteration 208
# total time 9.93310809135437
# iter 0 	max_abs_delta_F 0.49072350345943755 	max_abs_delta_Gamma_b 0.08315724646341997
# iter 100 	max_abs_delta_F 2.6625088088893953e-06 	max_abs_delta_Gamma_b 3.6394166392994866e-05
# iter 139 	max_abs_delta_F 7.279310969556844e-07 	max_abs_delta_Gamma_b 9.880478791284872e-06
# Elapsed time 5.210579872131348
# iteration 209
# total time 5.358419895172119
# iter 0 	max_abs_delta_F 0.49084179370875064 	max_abs_delta_Gamma_b 0.07426656862327344
# iter 100 	max_abs_delta_F 6.3199634868123024e-06 	max_abs_delta_Gamma_b 7.96948204681314e-05
# iter 161 	max_abs_delta_F 7.884765784611443e-07 	max_abs_delta_Gamma_b 9.812597866407034e-06
# Elapsed time 6.0967981815338135
# iteration 210
# total time 6.244099140167236
# iter 0 	max_abs_delta_F 0.4899075540883407 	max_abs_delta_Gamma_b 0.07691806591238426
# iter 100 	max_abs_delta_F 1.2291727006987896e-06 	max_abs_delta_Gamma_b 2.045397909377127e-05
# iter 130 	max_abs_delta_F 5.973532784477286e-07 	max_abs_delta_Gamma_b 9.99073171351793e-06
# Elapsed time 4.876282215118408
# iteration 211
# total time 5.015826940536499
# iter 0 	max_abs_delta_F 0.4905920296210041 	max_abs_delta_Gamma_b 0.08390555366678078
# iter 43 	max_abs_delta_F 5.927053752439602e-07 	max_abs_delta_Gamma_b 9.206427821554292e-06
# Elapsed time 1.6456279754638672
# iteration 212
# total time 1.785426139831543
# iter 0 	max_abs_delta_F 0.49142953690163826 	max_abs_delta_Gamma_b 0.08005337240819801
# iter 100 	max_abs_delta_F 1.1014946135569597e-06 	max_abs_delta_Gamma_b 1.6213962212345085e-05
# iter 109 	max_abs_delta_F 6.743222399950643e-07 	max_abs_delta_Gamma_b 9.924069213345804e-06
# Elapsed time 4.127448081970215
# iteration 213
# total time 4.267269849777222
# iter 0 	max_abs_delta_F 0.49082897951306387 	max_abs_delta_Gamma_b 0.09014980643755385
# iter 71 	max_abs_delta_F 7.283807664986266e-07 	max_abs_delta_Gamma_b 9.818423478907438e-06
# Elapsed time 2.6940479278564453
# iteration 214
# total time 2.8337152004241943
# iter 0 	max_abs_delta_F 0.49074029834361355 	max_abs_delta_Gamma_b 0.07903031569260688
# iter 96 	max_abs_delta_F 6.306284436440914e-07 	max_abs_delta_Gamma_b 9.628393947721638e-06
# Elapsed time 3.6132471561431885
# iteration 215
# total time 3.7498652935028076
# iter 0 	max_abs_delta_F 0.48993716403636756 	max_abs_delta_Gamma_b 0.06943510158901628
# iter 87 	max_abs_delta_F 6.449688768176535e-07 	max_abs_delta_Gamma_b 9.824126151481787e-06
# Elapsed time 3.2847728729248047
# iteration 216
# total time 3.4218223094940186
# iter 0 	max_abs_delta_F 0.4897587658950022 	max_abs_delta_Gamma_b 0.0793319359387057
# iter 100 	max_abs_delta_F 1.7870496331627901e-06 	max_abs_delta_Gamma_b 2.708042122607836e-05
# iter 128 	max_abs_delta_F 6.398778624193677e-07 	max_abs_delta_Gamma_b 9.75642939157866e-06
# Elapsed time 4.824069023132324
# iteration 217
# total time 4.96242618560791
# iter 0 	max_abs_delta_F 0.49003866644776745 	max_abs_delta_Gamma_b 0.07005819849680679
# iter 100 	max_abs_delta_F 1.5602170567738312e-06 	max_abs_delta_Gamma_b 2.2880039196085384e-05
# iter 116 	max_abs_delta_F 6.6783938854771e-07 	max_abs_delta_Gamma_b 9.782996877428657e-06
# Elapsed time 4.366077899932861
# iteration 218
# total time 4.503842115402222
# iter 0 	max_abs_delta_F 0.4904108377900616 	max_abs_delta_Gamma_b 0.07480450485320979
# iter 100 	max_abs_delta_F 1.1708125027946955e-06 	max_abs_delta_Gamma_b 1.6012384400347462e-05
# iter 107 	max_abs_delta_F 7.204745528384783e-07 	max_abs_delta_Gamma_b 9.798268968239379e-06
# Elapsed time 4.049430847167969
# iteration 219
# total time 4.188593149185181
# iter 0 	max_abs_delta_F 0.4904454702209017 	max_abs_delta_Gamma_b 0.07051848024035919
# iter 100 	max_abs_delta_F 4.303593530436301e-06 	max_abs_delta_Gamma_b 6.454143573836758e-05
# iter 182 	max_abs_delta_F 6.606196056064442e-07 	max_abs_delta_Gamma_b 9.892520304408742e-06
# Elapsed time 6.8534321784973145
# iteration 220
# total time 6.990717887878418
# iter 0 	max_abs_delta_F 0.49050024992518654 	max_abs_delta_Gamma_b 0.07710519649107478
# iter 79 	max_abs_delta_F 6.813545279897668e-07 	max_abs_delta_Gamma_b 9.534106004857936e-06
# Elapsed time 2.9860517978668213
# iteration 221
# total time 3.123324155807495
# iter 0 	max_abs_delta_F 0.49053823760435256 	max_abs_delta_Gamma_b 0.08242553055952122
# iter 100 	max_abs_delta_F 9.010702520376359e-06 	max_abs_delta_Gamma_b 0.0001496849573891136
# iter 179 	max_abs_delta_F 5.997875995114517e-07 	max_abs_delta_Gamma_b 9.914836217245127e-06
# Elapsed time 6.774715185165405
# iteration 222
# total time 6.915673017501831
# iter 0 	max_abs_delta_F 0.49026903315781206 	max_abs_delta_Gamma_b 0.07259499651899605
# iter 72 	max_abs_delta_F 7.000146159449719e-07 	max_abs_delta_Gamma_b 9.827854764994639e-06
# Elapsed time 2.7634592056274414
# iteration 223
# total time 2.898080825805664
# iter 0 	max_abs_delta_F 0.4904400669032682 	max_abs_delta_Gamma_b 0.08071723890845474
# iter 100 	max_abs_delta_F 2.8878490654355817e-06 	max_abs_delta_Gamma_b 4.5908313750933784e-05
# iter 175 	max_abs_delta_F 6.255507994404165e-07 	max_abs_delta_Gamma_b 9.924668091051362e-06
# Elapsed time 6.610574245452881
# iteration 224
# total time 6.767381906509399
# iter 0 	max_abs_delta_F 0.49099174821750197 	max_abs_delta_Gamma_b 0.07828595521159912
# iter 62 	max_abs_delta_F 6.770892831884703e-07 	max_abs_delta_Gamma_b 9.274712026159561e-06
# Elapsed time 2.349740982055664
# iteration 225
# total time 2.497629165649414
# iter 0 	max_abs_delta_F 0.4906313253907647 	max_abs_delta_Gamma_b 0.07671191821395142
# iter 100 	max_abs_delta_F 8.426235705800966e-07 	max_abs_delta_Gamma_b 1.2521302867763152e-05
# iter 105 	max_abs_delta_F 6.466455352459111e-07 	max_abs_delta_Gamma_b 9.602079317590314e-06
# Elapsed time 3.9768919944763184
# iteration 226
# total time 4.12870192527771
# iter 0 	max_abs_delta_F 0.4903049144533052 	max_abs_delta_Gamma_b 0.07571987568610432
# iter 100 	max_abs_delta_F 1.3317241095528192e-05 	max_abs_delta_Gamma_b 0.0002192901628614753
# iter 161 	max_abs_delta_F 6.118271092773861e-07 	max_abs_delta_Gamma_b 9.952915051815264e-06
# Elapsed time 6.044574975967407
# iteration 227
# total time 6.193349123001099
# iter 0 	max_abs_delta_F 0.4895641219984113 	max_abs_delta_Gamma_b 0.0777063617491046
# iter 100 	max_abs_delta_F 6.916862357607684e-07 	max_abs_delta_Gamma_b 1.0738548357533397e-05
# iter 102 	max_abs_delta_F 6.22998226212963e-07 	max_abs_delta_Gamma_b 9.677050574365844e-06
# Elapsed time 3.8606958389282227
# iteration 228
# total time 4.010204792022705
# iter 0 	max_abs_delta_F 0.49050587405460183 	max_abs_delta_Gamma_b 0.08064903039550297
# iter 100 	max_abs_delta_F 6.13286123747599e-07 	max_abs_delta_Gamma_b 9.767695384503536e-06
# Elapsed time 3.768657922744751
# iteration 229
# total time 3.9187707901000977
# iter 0 	max_abs_delta_F 0.49005795260663915 	max_abs_delta_Gamma_b 0.08283486203682995
# iter 100 	max_abs_delta_F 6.293457516385209e-07 	max_abs_delta_Gamma_b 9.285921357329708e-06
# Elapsed time 3.768036127090454
# iteration 230
# total time 3.91782808303833
# iter 0 	max_abs_delta_F 0.48970962887079694 	max_abs_delta_Gamma_b 0.07496991211682004
# iter 98 	max_abs_delta_F 6.427153975773004e-07 	max_abs_delta_Gamma_b 9.572135360134853e-06
# Elapsed time 3.7090578079223633
# iteration 231
# total time 3.857337713241577
# iter 0 	max_abs_delta_F 0.4904518124074561 	max_abs_delta_Gamma_b 0.08291050342176971
# iter 50 	max_abs_delta_F 6.152163038023783e-07 	max_abs_delta_Gamma_b 9.019014706129421e-06
# Elapsed time 1.901017189025879
# iteration 232
# total time 2.0504701137542725
# iter 0 	max_abs_delta_F 0.4903055612924211 	max_abs_delta_Gamma_b 0.07748009457180946
# iter 100 	max_abs_delta_F 1.1635231574740227e-06 	max_abs_delta_Gamma_b 1.8838413921707715e-05
# iter 118 	max_abs_delta_F 6.330596515763535e-07 	max_abs_delta_Gamma_b 9.886622142237535e-06
# Elapsed time 4.442706823348999
# iteration 233
# total time 4.591222763061523
# iter 0 	max_abs_delta_F 0.4896860448665842 	max_abs_delta_Gamma_b 0.0774563049294157
# iter 100 	max_abs_delta_F 5.505634811314749e-06 	max_abs_delta_Gamma_b 9.335380976410245e-05
# iter 152 	max_abs_delta_F 5.835167858452946e-07 	max_abs_delta_Gamma_b 9.763594147685369e-06
# Elapsed time 5.712770938873291
# iteration 234
# total time 5.865217924118042
# iter 0 	max_abs_delta_F 0.49035302879821285 	max_abs_delta_Gamma_b 0.07782612637249446
# iter 77 	max_abs_delta_F 6.214095575516428e-07 	max_abs_delta_Gamma_b 9.532108283882359e-06
# Elapsed time 2.9089908599853516
# iteration 235
# total time 3.0557539463043213
# iter 0 	max_abs_delta_F 0.49018086270389255 	max_abs_delta_Gamma_b 0.07296138701350909
# iter 100 	max_abs_delta_F 1.506682029631788e-05 	max_abs_delta_Gamma_b 0.00025407444572025787
# iter 200 	max_abs_delta_F 6.325075633715549e-07 	max_abs_delta_Gamma_b 1.0595235975091995e-05
# iter 202 	max_abs_delta_F 5.928403648113279e-07 	max_abs_delta_Gamma_b 9.930068802860524e-06
# Elapsed time 7.5962231159210205
# iteration 236
# total time 7.7401123046875
# iter 0 	max_abs_delta_F 0.4896907569253913 	max_abs_delta_Gamma_b 0.07219027129010297
# iter 60 	max_abs_delta_F 5.89542342489618e-07 	max_abs_delta_Gamma_b 9.663658603243464e-06
# Elapsed time 2.285489797592163
# iteration 237
# total time 2.4312896728515625
# iter 0 	max_abs_delta_F 0.4896513537165493 	max_abs_delta_Gamma_b 0.07459715096119857
# iter 56 	max_abs_delta_F 6.355490819788668e-07 	max_abs_delta_Gamma_b 9.584612844684656e-06
# Elapsed time 2.1354358196258545
# iteration 238
# total time 2.280195951461792
# iter 0 	max_abs_delta_F 0.48908497641405513 	max_abs_delta_Gamma_b 0.07018898005928374
# iter 100 	max_abs_delta_F 3.218793821872416e-06 	max_abs_delta_Gamma_b 4.8830663112312664e-05
# iter 131 	max_abs_delta_F 6.29136941086637e-07 	max_abs_delta_Gamma_b 9.55156942104617e-06
# Elapsed time 5.229511022567749
# iteration 239
# total time 5.373941898345947
# iter 0 	max_abs_delta_F 0.49009113800749055 	max_abs_delta_Gamma_b 0.0700290723431286
# iter 86 	max_abs_delta_F 7.500150956026374e-07 	max_abs_delta_Gamma_b 9.413761717909064e-06
# Elapsed time 3.25382399559021
# iteration 240
# total time 3.4040029048919678
# iter 0 	max_abs_delta_F 0.4895541718490789 	max_abs_delta_Gamma_b 0.0777398053598103
# iter 85 	max_abs_delta_F 5.982313937730428e-07 	max_abs_delta_Gamma_b 9.431250033287143e-06
# Elapsed time 3.3827192783355713
# iteration 241
# total time 3.5296192169189453
# iter 0 	max_abs_delta_F 0.4900128430091623 	max_abs_delta_Gamma_b 0.07754285739114355
# iter 100 	max_abs_delta_F 1.596547774898262e-06 	max_abs_delta_Gamma_b 2.1343783383513073e-05
# iter 113 	max_abs_delta_F 7.292800804830632e-07 	max_abs_delta_Gamma_b 9.742349803206045e-06
# Elapsed time 4.372242212295532
# iteration 242
# total time 4.525381088256836
# iter 0 	max_abs_delta_F 0.48937535410694216 	max_abs_delta_Gamma_b 0.08494750267516754
# iter 94 	max_abs_delta_F 6.239089989981406e-07 	max_abs_delta_Gamma_b 9.532462378317396e-06
# Elapsed time 3.731886625289917
# iteration 243
# total time 3.881495952606201
# iter 0 	max_abs_delta_F 0.4895220539560233 	max_abs_delta_Gamma_b 0.07650820155103297
# iter 100 	max_abs_delta_F 1.2194833283532625e-05 	max_abs_delta_Gamma_b 0.0001779934488946614
# iter 200 	max_abs_delta_F 1.362191237508746e-05 	max_abs_delta_Gamma_b 0.00020487977822063248
# iter 300 	max_abs_delta_F 3.32715603332177e-06 	max_abs_delta_Gamma_b 5.024399485119382e-05
# iter 400 	max_abs_delta_F 8.110866428023406e-07 	max_abs_delta_Gamma_b 1.2338729543664792e-05
# iter 416 	max_abs_delta_F 6.515369085991593e-07 	max_abs_delta_Gamma_b 9.916073371944877e-06
# Elapsed time 16.09194302558899
# iteration 244
# total time 16.24879789352417
# iter 0 	max_abs_delta_F 0.4901529471341232 	max_abs_delta_Gamma_b 0.07860012411916657
# iter 52 	max_abs_delta_F 5.945623475672065e-07 	max_abs_delta_Gamma_b 9.008153058140193e-06
# Elapsed time 1.9961977005004883
# iteration 245
# total time 2.141632080078125
# iter 0 	max_abs_delta_F 0.4894881358799479 	max_abs_delta_Gamma_b 0.07175786296990264
# iter 100 	max_abs_delta_F 4.3365851986868175e-06 	max_abs_delta_Gamma_b 6.637962044167615e-05
# iter 133 	max_abs_delta_F 6.404949483098202e-07 	max_abs_delta_Gamma_b 9.880036283375664e-06
# Elapsed time 5.022130966186523
# iteration 246
# total time 5.17104697227478
# iter 0 	max_abs_delta_F 0.49082466155487114 	max_abs_delta_Gamma_b 0.07379306276002215
# iter 100 	max_abs_delta_F 2.0844787263993815e-05 	max_abs_delta_Gamma_b 0.0003567921074787141
# iter 200 	max_abs_delta_F 1.0850918135657753e-06 	max_abs_delta_Gamma_b 1.878274262497116e-05
# iter 220 	max_abs_delta_F 5.608195439969408e-07 	max_abs_delta_Gamma_b 9.70533087009939e-06
# Elapsed time 8.420136213302612
# iteration 247
# total time 8.565591812133789
# iter 0 	max_abs_delta_F 0.4890104853509836 	max_abs_delta_Gamma_b 0.07046417475218608
# iter 86 	max_abs_delta_F 7.854375243660399e-07 	max_abs_delta_Gamma_b 9.489732890527134e-06
# Elapsed time 3.3114798069000244
# iteration 248
# total time 3.459372043609619
# iter 0 	max_abs_delta_F 0.48952000287646125 	max_abs_delta_Gamma_b 0.07295206303362253
# iter 100 	max_abs_delta_F 1.2087538327027056e-05 	max_abs_delta_Gamma_b 0.00018216918350614418
# iter 200 	max_abs_delta_F 1.479245497535739e-06 	max_abs_delta_Gamma_b 2.1542019483096022e-05
# iter 241 	max_abs_delta_F 6.884971935017809e-07 	max_abs_delta_Gamma_b 9.99022251747708e-06
# Elapsed time 9.159491777420044
# iteration 249
# total time 9.308336973190308
# iter 0 	max_abs_delta_F 0.4897265015935341 	max_abs_delta_Gamma_b 0.07165339513214602
# iter 91 	max_abs_delta_F 7.064624798047259e-07 	max_abs_delta_Gamma_b 9.723921019025005e-06
# Elapsed time 3.4505839347839355
# iteration 250
# total time 3.5975329875946045
# iter 0 	max_abs_delta_F 0.49009718881503994 	max_abs_delta_Gamma_b 0.0707811020535283
# iter 100 	max_abs_delta_F 2.1951173425799626e-06 	max_abs_delta_Gamma_b 3.0817580103341604e-05
# iter 129 	max_abs_delta_F 7.01159990872589e-07 	max_abs_delta_Gamma_b 9.666414364317796e-06
# Elapsed time 4.868376970291138
# iteration 251
# total time 5.014066219329834
# iter 0 	max_abs_delta_F 0.4914658788616044 	max_abs_delta_Gamma_b 0.06968440072934629
# iter 47 	max_abs_delta_F 6.186742079066692e-07 	max_abs_delta_Gamma_b 9.065940876546638e-06
# Elapsed time 1.7895410060882568
# iteration 252
# total time 1.9363718032836914
# iter 0 	max_abs_delta_F 0.4900503227019753 	max_abs_delta_Gamma_b 0.08165028390142937
# iter 68 	max_abs_delta_F 6.459784770924464e-07 	max_abs_delta_Gamma_b 9.972208217701636e-06
# Elapsed time 2.5958540439605713
# iteration 253
# total time 2.743285894393921
# iter 0 	max_abs_delta_F 0.49069417023041123 	max_abs_delta_Gamma_b 0.07957788285365315
# iter 100 	max_abs_delta_F 1.7825124027568082e-06 	max_abs_delta_Gamma_b 2.713377209884753e-05
# iter 115 	max_abs_delta_F 6.435401154788039e-07 	max_abs_delta_Gamma_b 9.78165457574269e-06
# Elapsed time 4.331457853317261
# iteration 254
# total time 4.4794700145721436
# iter 0 	max_abs_delta_F 0.4897787094711069 	max_abs_delta_Gamma_b 0.07827458770644949
# iter 73 	max_abs_delta_F 6.739328268140317e-07 	max_abs_delta_Gamma_b 9.860295573440823e-06
# Elapsed time 2.7695021629333496
# iteration 255
# total time 2.916388988494873
# iter 0 	max_abs_delta_F 0.4905043746395178 	max_abs_delta_Gamma_b 0.07693246004969066
# iter 100 	max_abs_delta_F 5.225444561211566e-06 	max_abs_delta_Gamma_b 8.298523747135865e-05
# iter 141 	max_abs_delta_F 6.158979636221528e-07 	max_abs_delta_Gamma_b 9.564470522073313e-06
# Elapsed time 5.415283918380737
# iteration 256
# total time 5.561553955078125
# iter 0 	max_abs_delta_F 0.4907800541554004 	max_abs_delta_Gamma_b 0.08904483477594256
# iter 61 	max_abs_delta_F 7.365873363491535e-07 	max_abs_delta_Gamma_b 9.330133369475061e-06
# Elapsed time 2.3196468353271484
# iteration 257
# total time 2.4656660556793213
# iter 0 	max_abs_delta_F 0.49000621251234255 	max_abs_delta_Gamma_b 0.08354362526368872
# iter 82 	max_abs_delta_F 6.380540548995683e-07 	max_abs_delta_Gamma_b 9.462672816711885e-06
# Elapsed time 3.098551034927368
# iteration 258
# total time 3.248363971710205
# iter 0 	max_abs_delta_F 0.49078496537774813 	max_abs_delta_Gamma_b 0.08279990779659033
# iter 100 	max_abs_delta_F 4.866677461265368e-06 	max_abs_delta_Gamma_b 7.432886748207856e-05
# iter 156 	max_abs_delta_F 6.400913797190937e-07 	max_abs_delta_Gamma_b 9.799438204175644e-06
# Elapsed time 5.91867208480835
# iteration 259
# total time 6.066411018371582
# iter 0 	max_abs_delta_F 0.48984115802092687 	max_abs_delta_Gamma_b 0.06896248822336327
# iter 80 	max_abs_delta_F 6.147385811288625e-07 	max_abs_delta_Gamma_b 9.91528354313655e-06
# Elapsed time 3.050348997116089
# iteration 260
# total time 3.197138786315918
# iter 0 	max_abs_delta_F 0.49013558723014855 	max_abs_delta_Gamma_b 0.07592250943864845
# iter 78 	max_abs_delta_F 6.638715103063719e-07 	max_abs_delta_Gamma_b 9.721584663269435e-06
# Elapsed time 2.9617931842803955
# iteration 261
# total time 3.1105191707611084
# iter 0 	max_abs_delta_F 0.4899457926140349 	max_abs_delta_Gamma_b 0.08667837746920194
# iter 35 	max_abs_delta_F 6.663665720761091e-07 	max_abs_delta_Gamma_b 9.99749233430184e-06
# Elapsed time 1.353043794631958
# iteration 262
# total time 1.4994807243347168
# iter 0 	max_abs_delta_F 0.49058358781654415 	max_abs_delta_Gamma_b 0.07827269502490392
# iter 55 	max_abs_delta_F 6.977195976907006e-07 	max_abs_delta_Gamma_b 9.462430024915554e-06
# Elapsed time 2.0945708751678467
# iteration 263
# total time 2.240295886993408
# iter 0 	max_abs_delta_F 0.48976554634957753 	max_abs_delta_Gamma_b 0.07518553554748642
# iter 62 	max_abs_delta_F 5.803717309450779e-07 	max_abs_delta_Gamma_b 9.222355626175654e-06
# Elapsed time 2.4001779556274414
# iteration 264
# total time 2.7014031410217285
# iter 0 	max_abs_delta_F 0.4907189914956107 	max_abs_delta_Gamma_b 0.08629070719358774
# iter 74 	max_abs_delta_F 5.006563645134781e-07 	max_abs_delta_Gamma_b 9.517064396558026e-06
# Elapsed time 2.8289971351623535
# iteration 265
# total time 3.138256311416626
# iter 0 	max_abs_delta_F 0.48987439200471866 	max_abs_delta_Gamma_b 0.07423781455226262
# iter 100 	max_abs_delta_F 4.778258863395206e-06 	max_abs_delta_Gamma_b 7.46345151128122e-05
# iter 167 	max_abs_delta_F 6.359541556059846e-07 	max_abs_delta_Gamma_b 9.92864671860555e-06
# Elapsed time 6.3470778465271
# iteration 266
# total time 6.638724088668823
# iter 0 	max_abs_delta_F 0.4903770541178505 	max_abs_delta_Gamma_b 0.07663201481062047
# iter 62 	max_abs_delta_F 4.861169052778065e-07 	max_abs_delta_Gamma_b 9.327514819711056e-06
# Elapsed time 2.3499670028686523
# iteration 267
# total time 2.6596102714538574
# iter 0 	max_abs_delta_F 0.4906367891054728 	max_abs_delta_Gamma_b 0.07776880300338009
# iter 71 	max_abs_delta_F 6.663085640004661e-07 	max_abs_delta_Gamma_b 9.773851004232367e-06
# Elapsed time 2.6924009323120117
# iteration 268
# total time 2.9719769954681396
# iter 0 	max_abs_delta_F 0.4904663068254997 	max_abs_delta_Gamma_b 0.07592489495188863
# iter 100 	max_abs_delta_F 1.6663767902229413e-06 	max_abs_delta_Gamma_b 2.9398969713379123e-05
# iter 125 	max_abs_delta_F 5.495921442169856e-07 	max_abs_delta_Gamma_b 9.661037536726453e-06
# Elapsed time 4.687559127807617
# iteration 269
# total time 4.950999021530151
# iter 0 	max_abs_delta_F 0.4895243537698758 	max_abs_delta_Gamma_b 0.07193336538454992
# iter 100 	max_abs_delta_F 9.417461986176006e-06 	max_abs_delta_Gamma_b 0.00013535467508923833
# iter 200 	max_abs_delta_F 1.177704962650407e-06 	max_abs_delta_Gamma_b 1.690591394485293e-05
# iter 226 	max_abs_delta_F 6.832152479596125e-07 	max_abs_delta_Gamma_b 9.8063246884407e-06
# Elapsed time 8.5015549659729
# iteration 270
# total time 8.831799983978271
# iter 0 	max_abs_delta_F 0.4909433851018482 	max_abs_delta_Gamma_b 0.08119964310250999
# iter 51 	max_abs_delta_F 6.912702021448145e-07 	max_abs_delta_Gamma_b 9.854136185628242e-06
# Elapsed time 1.9816291332244873
# iteration 271
# total time 2.2505998611450195
# iter 0 	max_abs_delta_F 0.49004954120385746 	max_abs_delta_Gamma_b 0.12198229828561155
# iter 74 	max_abs_delta_F 5.405726485240355e-07 	max_abs_delta_Gamma_b 9.389446366894972e-06
# Elapsed time 2.8517069816589355
# iteration 272
# total time 3.1220688819885254
# iter 0 	max_abs_delta_F 0.4904585775375549 	max_abs_delta_Gamma_b 0.10631808158554716
# iter 100 	max_abs_delta_F 7.094182414783042e-07 	max_abs_delta_Gamma_b 1.146767666306307e-05
# iter 102 	max_abs_delta_F 6.162236573859265e-07 	max_abs_delta_Gamma_b 9.961691765742044e-06
# Elapsed time 3.831315040588379
# iteration 273
# total time 4.099759817123413
# iter 0 	max_abs_delta_F 0.49075614041934196 	max_abs_delta_Gamma_b 0.11340674441441699
# iter 100 	max_abs_delta_F 1.026004547981588e-06 	max_abs_delta_Gamma_b 1.7778536184335394e-05
# iter 108 	max_abs_delta_F 5.464579035540249e-07 	max_abs_delta_Gamma_b 9.469659921371474e-06
# Elapsed time 4.0699241161346436
# iteration 274
# total time 4.338414192199707
# iter 0 	max_abs_delta_F 0.49024939434711995 	max_abs_delta_Gamma_b 0.11666408317014974
# iter 73 	max_abs_delta_F 6.512957413335668e-07 	max_abs_delta_Gamma_b 9.69627369156274e-06
# Elapsed time 2.777343988418579
# iteration 275
# total time 3.045650005340576
# ...
# iter 38 	max_abs_delta_F 7.185789977075018e-07 	max_abs_delta_Gamma_b 8.465649559637016e-06
# Elapsed time 1.4484949111938477
# iteration 467
# total time 1.7002789974212646
# iter 0 	max_abs_delta_F 0.490592643582317 	max_abs_delta_Gamma_b 0.08647737633095404
# iter 50 	max_abs_delta_F 7.449994473610445e-07 	max_abs_delta_Gamma_b 9.659198056986974e-06
# Elapsed time 1.9152960777282715
# iteration 468
# total time 2.1657907962799072
# iter 0 	max_abs_delta_F 0.4903509605239804 	max_abs_delta_Gamma_b 0.08336245893486312
# iter 77 	max_abs_delta_F 8.189480926164676e-07 	max_abs_delta_Gamma_b 9.453308967484446e-06
# Elapsed time 2.916144847869873
# iteration 469
# total time 3.167738914489746
# iter 0 	max_abs_delta_F 0.4911819067613643 	max_abs_delta_Gamma_b 0.07834644179874171
# iter 100 	max_abs_delta_F 2.9029412118347906e-06 	max_abs_delta_Gamma_b 3.67282384159026e-05
# iter 119 	max_abs_delta_F 7.840389887950585e-07 	max_abs_delta_Gamma_b 9.917635216637979e-06
# Elapsed time 4.489185094833374
# iteration 470
# total time 4.734082937240601
# iter 0 	max_abs_delta_F 0.4901458119340903 	max_abs_delta_Gamma_b 0.07810298350979858
# iter 69 	max_abs_delta_F 7.415020907491821e-07 	max_abs_delta_Gamma_b 9.734270388708102e-06
# Elapsed time 2.6122617721557617
# iteration 471
# total time 2.8553128242492676
# iter 0 	max_abs_delta_F 0.49053499015357865 	max_abs_delta_Gamma_b 0.08897546357128919
# iter 100 	max_abs_delta_F 1.1144030706791361e-05 	max_abs_delta_Gamma_b 0.0001536524468958356
# iter 200 	max_abs_delta_F 6.03726839705107e-05 	max_abs_delta_Gamma_b 0.0008080216818600652
# iter 296 	max_abs_delta_F 8.082918174425932e-07 	max_abs_delta_Gamma_b 9.949339683440561e-06
# Elapsed time 11.184188842773438
# iteration 472
# total time 11.423517227172852
# iter 0 	max_abs_delta_F 0.4905068486661835 	max_abs_delta_Gamma_b 0.08644637437071048
# iter 100 	max_abs_delta_F 9.864373338595417e-07 	max_abs_delta_Gamma_b 1.1099656568260258e-05
# iter 102 	max_abs_delta_F 8.846174166454342e-07 	max_abs_delta_Gamma_b 9.95459926227123e-06
# Elapsed time 3.8709487915039062
# iteration 473
# total time 4.110026121139526
# iter 0 	max_abs_delta_F 0.490689607656783 	max_abs_delta_Gamma_b 0.0814050995376378
# iter 82 	max_abs_delta_F 7.017594993463825e-07 	max_abs_delta_Gamma_b 9.7048854988885e-06
# Elapsed time 3.1129117012023926
# iteration 474
# total time 3.355415105819702
# iter 0 	max_abs_delta_F 0.4900615208218712 	max_abs_delta_Gamma_b 0.08565073029793174
# iter 75 	max_abs_delta_F 7.988627468855503e-07 	max_abs_delta_Gamma_b 9.362314179893211e-06
# Elapsed time 2.8456318378448486
# iteration 475
# total time 3.0798442363739014
# iter 0 	max_abs_delta_F 0.49063048799260806 	max_abs_delta_Gamma_b 0.08537270544135087
# iter 31 	max_abs_delta_F 6.396029368514821e-07 	max_abs_delta_Gamma_b 9.931031685928575e-06
# Elapsed time 1.2443697452545166
# iteration 476
# total time 1.4781732559204102
# iter 0 	max_abs_delta_F 0.48980346453700935 	max_abs_delta_Gamma_b 0.08875996456260588
# iter 84 	max_abs_delta_F 6.547759148967284e-07 	max_abs_delta_Gamma_b 9.607307085926893e-06
# Elapsed time 3.834747076034546
# iteration 477
# total time 4.078464031219482
# iter 0 	max_abs_delta_F 0.4909456202124971 	max_abs_delta_Gamma_b 0.09420217729434464
# iter 100 	max_abs_delta_F 7.545924015365062e-07 	max_abs_delta_Gamma_b 9.884365579621333e-06
# Elapsed time 3.847805976867676
# iteration 478
# total time 4.1037657260894775
# iter 0 	max_abs_delta_F 0.4908995059988002 	max_abs_delta_Gamma_b 0.07901990236635933
# iter 100 	max_abs_delta_F 3.1600920764208704e-06 	max_abs_delta_Gamma_b 4.391593049531323e-05
# iter 132 	max_abs_delta_F 6.796912582129084e-07 	max_abs_delta_Gamma_b 9.561351145814136e-06
# Elapsed time 5.012025833129883
# iteration 479
# total time 5.242743015289307
# iter 0 	max_abs_delta_F 0.48972146154076374 	max_abs_delta_Gamma_b 0.08861611537156579
# iter 48 	max_abs_delta_F 8.534403340873429e-07 	max_abs_delta_Gamma_b 9.757122805307295e-06
# Elapsed time 1.8318240642547607
# iteration 480
# total time 2.0598349571228027
# iter 0 	max_abs_delta_F 0.48993780089279637 	max_abs_delta_Gamma_b 0.07435790335329646
# iter 100 	max_abs_delta_F 4.015423301817286e-05 	max_abs_delta_Gamma_b 0.0005257747459832817
# iter 200 	max_abs_delta_F 1.7118775461524864e-06 	max_abs_delta_Gamma_b 2.3319642733478885e-05
# iter 219 	max_abs_delta_F 7.083175864062857e-07 	max_abs_delta_Gamma_b 9.653822383874941e-06
# Elapsed time 8.209794998168945
# iteration 481
# total time 8.436969995498657
# iter 0 	max_abs_delta_F 0.49027609285094964 	max_abs_delta_Gamma_b 0.07824061267185052
# iter 87 	max_abs_delta_F 8.321848130345483e-07 	max_abs_delta_Gamma_b 9.352327367299994e-06
# Elapsed time 3.312800884246826
# iteration 482
# total time 3.536320209503174
# iter 0 	max_abs_delta_F 0.49067007439928423 	max_abs_delta_Gamma_b 0.07988048635532417
# iter 100 	max_abs_delta_F 7.009706238109817e-07 	max_abs_delta_Gamma_b 1.2798391307784907e-05
# iter 105 	max_abs_delta_F 5.325277436443186e-07 	max_abs_delta_Gamma_b 9.71898198379887e-06
# Elapsed time 3.973318099975586
# iteration 483
# total time 4.19691276550293
# iter 0 	max_abs_delta_F 0.4888843888809127 	max_abs_delta_Gamma_b 0.08030666246935997
# iter 64 	max_abs_delta_F 7.184153509447906e-07 	max_abs_delta_Gamma_b 9.068955643579664e-06
# Elapsed time 2.438728094100952
# iteration 484
# total time 2.6586201190948486
# iter 0 	max_abs_delta_F 0.49005859248351225 	max_abs_delta_Gamma_b 0.08179849415259748
# iter 59 	max_abs_delta_F 7.648474312541426e-07 	max_abs_delta_Gamma_b 9.061498867183296e-06
# Elapsed time 2.2451441287994385
# iteration 485
# total time 2.465256929397583
# iter 0 	max_abs_delta_F 0.49058587961849526 	max_abs_delta_Gamma_b 0.10496835549603047
# iter 50 	max_abs_delta_F 7.707220519186776e-07 	max_abs_delta_Gamma_b 9.33978593412395e-06
# Elapsed time 1.9572639465332031
# iteration 486
# total time 2.180636167526245
# iter 0 	max_abs_delta_F 0.49094695313929554 	max_abs_delta_Gamma_b 0.06858141404928715
# iter 100 	max_abs_delta_F 8.468339461541759e-07 	max_abs_delta_Gamma_b 1.1012881955781468e-05
# iter 102 	max_abs_delta_F 7.528803423794558e-07 	max_abs_delta_Gamma_b 9.791846833765829e-06
# Elapsed time 3.8883349895477295
# iteration 487
# total time 4.101912975311279
# iter 0 	max_abs_delta_F 0.4898092154580826 	max_abs_delta_Gamma_b 0.07923473463465111
# iter 84 	max_abs_delta_F 7.244880853458972e-07 	max_abs_delta_Gamma_b 9.400665353717756e-06
# Elapsed time 3.214698076248169
# iteration 488
# total time 3.4299521446228027
# iter 0 	max_abs_delta_F 0.4899780269017222 	max_abs_delta_Gamma_b 0.08148964432534096
# iter 100 	max_abs_delta_F 1.1531196985080174e-06 	max_abs_delta_Gamma_b 1.7099961671536474e-05
# iter 110 	max_abs_delta_F 6.435830837149487e-07 	max_abs_delta_Gamma_b 9.592243260055609e-06
# Elapsed time 4.196375846862793
# iteration 489
# total time 4.407739162445068
# iter 0 	max_abs_delta_F 0.4904560493795113 	max_abs_delta_Gamma_b 0.07959147790039686
# iter 100 	max_abs_delta_F 1.8782746574379162e-05 	max_abs_delta_Gamma_b 0.00022696023990708875
# iter 163 	max_abs_delta_F 8.070017562638925e-07 	max_abs_delta_Gamma_b 9.697525153829513e-06
# Elapsed time 6.190992832183838
# iteration 490
# total time 6.400498867034912
# iter 0 	max_abs_delta_F 0.4899913037869579 	max_abs_delta_Gamma_b 0.08313515458997617
# iter 65 	max_abs_delta_F 7.594248425269812e-07 	max_abs_delta_Gamma_b 9.498796944263475e-06
# Elapsed time 2.4978809356689453
# iteration 491
# total time 2.7072510719299316
# iter 0 	max_abs_delta_F 0.4902560598615926 	max_abs_delta_Gamma_b 0.08526589682051935
# iter 100 	max_abs_delta_F 9.97924374005773e-07 	max_abs_delta_Gamma_b 1.4301364593898921e-05
# iter 139 	max_abs_delta_F 6.939323229455354e-07 	max_abs_delta_Gamma_b 9.940770770180326e-06
# Elapsed time 5.320943832397461
# iteration 492
# total time 5.538083076477051
# iter 0 	max_abs_delta_F 0.4913868903070298 	max_abs_delta_Gamma_b 0.08456288768274348
# iter 57 	max_abs_delta_F 7.249455062054478e-07 	max_abs_delta_Gamma_b 9.314755562339647e-06
# Elapsed time 2.186577081680298
# iteration 493
# total time 2.3935492038726807
# iter 0 	max_abs_delta_F 0.49070581259903756 	max_abs_delta_Gamma_b 0.08274173954852727
# iter 100 	max_abs_delta_F 1.5609834638883275e-06 	max_abs_delta_Gamma_b 2.4406001821212946e-05
# iter 138 	max_abs_delta_F 6.356824356788427e-07 	max_abs_delta_Gamma_b 9.926255096251788e-06
# Elapsed time 5.256116151809692
# iteration 494
# total time 5.459665775299072
# iter 0 	max_abs_delta_F 0.4902250215364445 	max_abs_delta_Gamma_b 0.0873444687649371
# iter 100 	max_abs_delta_F 2.74303938619181e-05 	max_abs_delta_Gamma_b 0.0003655643635808467
# iter 200 	max_abs_delta_F 2.9627377340457697e-06 	max_abs_delta_Gamma_b 3.7739019415735796e-05
# iter 245 	max_abs_delta_F 7.713572982703702e-07 	max_abs_delta_Gamma_b 9.807682619887654e-06
# Elapsed time 9.255039930343628
# iteration 495
# total time 9.45865797996521
# iter 0 	max_abs_delta_F 0.4917780479270778 	max_abs_delta_Gamma_b 0.08145588409900753
# iter 75 	max_abs_delta_F 6.872112146779514e-07 	max_abs_delta_Gamma_b 9.434299316371037e-06
# Elapsed time 2.883424997329712
# iteration 496
# total time 3.0858688354492188
# iter 0 	max_abs_delta_F 0.49027662603791056 	max_abs_delta_Gamma_b 0.07924868828615611
# iter 100 	max_abs_delta_F 2.1978968725707295e-05 	max_abs_delta_Gamma_b 0.0002482856256380657
# iter 200 	max_abs_delta_F 2.5591384211776157e-05 	max_abs_delta_Gamma_b 0.00027651771495269356
# iter 300 	max_abs_delta_F 2.2462028264868848e-06 	max_abs_delta_Gamma_b 2.321819541113661e-05
# iter 326 	max_abs_delta_F 9.519858255804137e-07 	max_abs_delta_Gamma_b 9.831832169676512e-06
# Elapsed time 12.357614994049072
# iteration 497
# total time 12.557339906692505
# iter 0 	max_abs_delta_F 0.49109589541867327 	max_abs_delta_Gamma_b 0.06815906341346178
# iter 77 	max_abs_delta_F 6.634846827682855e-07 	max_abs_delta_Gamma_b 9.323838919397761e-06
# Elapsed time 2.947273015975952
# iteration 498
# total time 3.154966115951538
# iter 0 	max_abs_delta_F 0.49019618698159395 	max_abs_delta_Gamma_b 0.0698115987586057
# iter 51 	max_abs_delta_F 8.621163795303378e-07 	max_abs_delta_Gamma_b 9.393489196878293e-06
# Elapsed time 1.9654829502105713
# iteration 499
# total time 2.166364908218384
# iter 0 	max_abs_delta_F 0.4902994075843377 	max_abs_delta_Gamma_b 0.09251448418149931
# iter 52 	max_abs_delta_F 7.518455839652825e-07 	max_abs_delta_Gamma_b 9.640672321429587e-06
# Elapsed time 2.017508029937744
# iteration 500
# total time 2.215385913848877
# iter 0 	max_abs_delta_F 0.49130091546557036 	max_abs_delta_Gamma_b 0.07469302909140531
# iter 100 	max_abs_delta_F 4.526382270191934e-06 	max_abs_delta_Gamma_b 5.992024560248906e-05
# iter 147 	max_abs_delta_F 7.329876885776688e-07 	max_abs_delta_Gamma_b 9.716878203632021e-06
# Elapsed time 5.586672782897949
# iteration 501
# total time 5.785564184188843
# iter 0 	max_abs_delta_F 0.489647575919988 	max_abs_delta_Gamma_b 0.0858344198049323
# iter 42 	max_abs_delta_F 7.860893743039334e-07 	max_abs_delta_Gamma_b 9.890033745211053e-06
# Elapsed time 1.629274845123291
# iteration 502
# total time 1.8236331939697266
# iter 0 	max_abs_delta_F 0.49023111330513297 	max_abs_delta_Gamma_b 0.07829378472719717
# iter 40 	max_abs_delta_F 7.361195798813949e-07 	max_abs_delta_Gamma_b 8.779783760966936e-06
# Elapsed time 1.5479230880737305
# iteration 503
# total time 1.7418348789215088
# iter 0 	max_abs_delta_F 0.49034249321777673 	max_abs_delta_Gamma_b 0.08975889860808756
# iter 93 	max_abs_delta_F 7.743562266918977e-07 	max_abs_delta_Gamma_b 9.432087251707741e-06
# Elapsed time 3.5708510875701904
# iteration 504
# total time 3.7616798877716064
# iter 0 	max_abs_delta_F 0.490599077692052 	max_abs_delta_Gamma_b 0.07774986042859908
# iter 53 	max_abs_delta_F 8.126486083634769e-07 	max_abs_delta_Gamma_b 9.440592864182715e-06
# Elapsed time 2.020207166671753
# iteration 505
# total time 2.2092151641845703
# iter 0 	max_abs_delta_F 0.49064919339060176 	max_abs_delta_Gamma_b 0.08472516505476671
# iter 100 	max_abs_delta_F 4.282253331359756e-06 	max_abs_delta_Gamma_b 7.203965370568399e-05
# iter 158 	max_abs_delta_F 5.848915980767809e-07 	max_abs_delta_Gamma_b 9.748119417969571e-06
# Elapsed time 5.965991973876953
# iteration 506
# total time 6.15377402305603
# iter 0 	max_abs_delta_F 0.4909229456734587 	max_abs_delta_Gamma_b 0.08077797421173132
# iter 60 	max_abs_delta_F 6.466184432753257e-07 	max_abs_delta_Gamma_b 9.610879036805749e-06
# Elapsed time 2.292886972427368
# iteration 507
# total time 2.481498956680298
# iter 0 	max_abs_delta_F 0.49029810565010956 	max_abs_delta_Gamma_b 0.0956397967614623
# iter 87 	max_abs_delta_F 6.169649304330999e-07 	max_abs_delta_Gamma_b 9.753073225772234e-06
# Elapsed time 3.286771059036255
# iteration 508
# total time 3.473339080810547
# iter 0 	max_abs_delta_F 0.49082077651443007 	max_abs_delta_Gamma_b 0.09489336378308047
# iter 60 	max_abs_delta_F 7.126296691011024e-07 	max_abs_delta_Gamma_b 9.225521531435238e-06
# Elapsed time 2.2926011085510254
# iteration 509
# total time 2.4796621799468994
# iter 0 	max_abs_delta_F 0.4912895536376822 	max_abs_delta_Gamma_b 0.0741066239816944
# iter 100 	max_abs_delta_F 1.2472117942544327e-06 	max_abs_delta_Gamma_b 1.938221239689846e-05
# iter 111 	max_abs_delta_F 6.408037757126066e-07 	max_abs_delta_Gamma_b 9.92646156251567e-06
# Elapsed time 4.188523054122925
# iteration 510
# total time 4.385711908340454
# iter 0 	max_abs_delta_F 0.4900855237681845 	max_abs_delta_Gamma_b 0.08530952111004719
# iter 52 	max_abs_delta_F 6.244623463549515e-07 	max_abs_delta_Gamma_b 8.725686179467672e-06
# Elapsed time 1.9849059581756592
# iteration 511
# total time 2.1773438453674316
# iter 0 	max_abs_delta_F 0.4900810111194666 	max_abs_delta_Gamma_b 0.08633621105253834
# iter 60 	max_abs_delta_F 6.662532682709439e-07 	max_abs_delta_Gamma_b 9.731397618945548e-06
# Elapsed time 2.2804648876190186
# iteration 512
# total time 2.470554828643799
# iter 0 	max_abs_delta_F 0.4903976739046047 	max_abs_delta_Gamma_b 0.0780110311400173
# iter 57 	max_abs_delta_F 7.859512936355729e-07 	max_abs_delta_Gamma_b 9.144885432669991e-06
# Elapsed time 2.1672918796539307
# iteration 513
# total time 2.358367919921875
# iter 0 	max_abs_delta_F 0.4900935847006511 	max_abs_delta_Gamma_b 0.08758798626161622
# iter 100 	max_abs_delta_F 1.1390527357172705e-06 	max_abs_delta_Gamma_b 1.4918459817161465e-05
# iter 108 	max_abs_delta_F 7.294048103158748e-07 	max_abs_delta_Gamma_b 9.571059694150597e-06
# Elapsed time 4.081510782241821
# iteration 514
# total time 4.27033805847168
# iter 0 	max_abs_delta_F 0.49086093115499996 	max_abs_delta_Gamma_b 0.08493742003137188
# iter 62 	max_abs_delta_F 6.248634907287996e-07 	max_abs_delta_Gamma_b 9.273388837615026e-06
# Elapsed time 2.3596129417419434
# iteration 515
# total time 2.5457170009613037
# iter 0 	max_abs_delta_F 0.4901119818658136 	max_abs_delta_Gamma_b 0.08508267860332751
# iter 100 	max_abs_delta_F 2.4741538395913564e-06 	max_abs_delta_Gamma_b 4.150752679396382e-05
# iter 154 	max_abs_delta_F 5.899233743027358e-07 	max_abs_delta_Gamma_b 9.969119090596102e-06
# Elapsed time 5.8036417961120605
# iteration 516
# total time 5.989384412765503
# iter 0 	max_abs_delta_F 0.49051143898964583 	max_abs_delta_Gamma_b 0.08841199778897237
# iter 100 	max_abs_delta_F 3.4979700674657467e-06 	max_abs_delta_Gamma_b 5.160294616856625e-05
# iter 143 	max_abs_delta_F 6.6168909459706e-07 	max_abs_delta_Gamma_b 9.667668626110935e-06
# Elapsed time 5.441661834716797
# iteration 517
# total time 5.630514144897461
# iter 0 	max_abs_delta_F 0.49023343892618876 	max_abs_delta_Gamma_b 0.07918416052756343
# iter 44 	max_abs_delta_F 6.562649257563162e-07 	max_abs_delta_Gamma_b 8.688408831541944e-06
# Elapsed time 1.7085800170898438
# iteration 518
# total time 1.8920300006866455
# iter 0 	max_abs_delta_F 0.49004522708993314 	max_abs_delta_Gamma_b 0.07515501900245278
# iter 66 	max_abs_delta_F 7.171771027259325e-07 	max_abs_delta_Gamma_b 9.387887960575554e-06
# Elapsed time 2.5353569984436035
# iteration 519
# total time 2.7175517082214355
# iter 0 	max_abs_delta_F 0.4893557338807483 	max_abs_delta_Gamma_b 0.07999441720775227
# iter 100 	max_abs_delta_F 3.568642361786239e-06 	max_abs_delta_Gamma_b 5.2835234805881564e-05
# iter 147 	max_abs_delta_F 6.648033880663217e-07 	max_abs_delta_Gamma_b 9.994412177223211e-06
# Elapsed time 5.580582857131958
# iteration 520
# total time 5.763225793838501

# %%
np.savetxt("./results/fact_ret_restricted_pca_init.csv", fact_ret, delimiter=",")

# %%
port_ret = np.mean(fact_ret,axis=0)
port_mean = np.mean(port_ret)
port_sd = np.std(port_ret)
port_mean/port_sd
# Out:
# 0.05394775899079859

# %%
import numpy as np
# fact_ret = np.loadtxt("./results/fact_ret_restricted_rand_init.csv", delimiter=",")
fact_ret = np.loadtxt("./results/fact_ret_restricted_pca_init.csv", delimiter=",")
fact_mean = np.mean(fact_ret,axis=1)
fact_var= np.cov(fact_ret)
np.sqrt(fact_mean.T.dot(np.linalg.inv(fact_var)).dot(fact_mean))*np.sqrt(12)
# Out:
# 0.24545864248901694

# %%
np.amax( np.abs(fact_mean) / np.sqrt(np.diag(fact_var)) )*np.sqrt(12)
# Out:
# 0.21091748509025066

# %%
fact_mean
# Out:
# array([3.34776804e-04, 8.61772129e-05, 8.76569729e-04, 5.84016264e-04,
#        1.46222387e-04])

# %% [markdown]
# ## All stocks

# %%
K = 5
Zts = np.array(Zts_test, copy = True)
Zt_cov = np.zeros((Zts.shape[1],Zts.shape[1],Zts.shape[2]))
x_t = np.zeros((Zts.shape[1],Zts.shape[2]))
for i in range(Zts.shape[2]):
    Zt = Zts[stock_presence[:,i],:,i]
    assert(np.amax(Zt)<=0.5)
    assert(np.amin(Zt)>=-0.5)
    Zt_cov[:,:,i] = (Zt.T).dot(Zt)
    if i<Zts.shape[2]-1:
        x_t[:,i] = (Zt.T).dot(rs[stock_presence[:,i],i+1])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-46-2d0d41f20abe> in <module>
#       5 for i in range(Zts.shape[2]):
#       6     Zt = Zts[stock_presence[:,i],:,i]
# ----> 7     assert(np.amax(Zt)<=0.5)
#       8     assert(np.amin(Zt)>=-0.5)
#       9     Zt_cov[:,:,i] = (Zt.T).dot(Zt)
#
# AssertionError:

# %%
print(np.amin(Zt))
print(np.amax(Zt))
# Out:
# -0.49412258606213266
# 5.8727959697733

# %%
mat = np.zeros_like(Zt_cov)
diagonals = np.zeros(Zts.shape[1:])
singular_values = np.zeros(Zts.shape[1:])
traces = np.zeros(Zts.shape[2])
negative_off_diag = np.zeros(Zts.shape[2])
for i in range(Zts.shape[2]):
    #mat[:,:,i] = (np.linalg.inv(np.linalg.cholesky(Zts[:,:,i].T.dot(Zts[:,:,i]))).dot(Zts[:,:,i].T)).T
    mat[:,:,i] = np.linalg.inv(Zt_cov[:,:,i])#/np.sum(stock_presence[:,i]))
    #mat = Zts[:,:,i].T
    U, S, V = np.linalg.svd(mat[:,:,i])
    singular_values[:,i] = S
    #traces[i] = np.trace(mat[:,:,i])
    traces[i] = np.sum(S)
    diagonals[:,i] = np.diag(mat[:,:,i])
    #diagonals[:,i] = mat[:,0,i]
    #negative_off_diag[i] = np.sum(mat < 0)/Zts.shape[1]/(Zts.shape[1]-1)
    #negative_off_diag[i] = np.sum(mat[mat < 0])
